# %% [markdown]
# <a href="https://colab.research.google.com/github/ellajanegates/cs72-final-project/blob/main/Train_Forced_Aligner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing Conda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2024-06-02 00:23:32--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143808873 (137M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 137.15M   161MB/s    in 0.9s
#
# 2024-06-02 00:23:33 (161 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [143808873/143808873]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# updating python path
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !eval "$(/usr/local/bin/conda shell.bash hook)"
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda create -n aligner -c conda-forge montreal-forced-aligner -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/aligner
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     aom-3.9.0                  |       hac33072_0         2.6 MB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     audioread-3.0.1            |   py39hf3d152e_1          36 KB  conda-forge
#     baumwelch-0.3.8            |       h00ab1b0_1         370 KB  conda-forge
#     biopython-1.79             |   py39hb9d737c_3         2.6 MB  conda-forge
# ...

# %%
# !source activate aligner

# %%
# !conda run -n aligner mfa --help
# Out:
#
#  Usage: mfa [OPTIONS] COMMAND [ARGS]...
#
#  Montreal Forced Aligner is a command line utility for aligning speech and text.
#
# ╭─ Options ────────────────────────────────────────────────────────────────────────────────────────╮
# │ --help      Show this message and exit.                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ───────────────────────────────────────────────────────────────────────────────────────╮
# │ adapt                Adapt an acoustic model                                                     │
# │ align                Align a corpus                                                              │
# │ align_one            Align a single file                                                         │
# │ anchor               Launch Anchor                                                               │
# ...

# %%
# !unzip /content/drive/MyDrive/CS72FinalProject/cim-wavs-20230517.zip -d /content/drive/MyDrive/CS72FinalProject/cim-wavs
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/AAN-RRAAT8-091.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/AAN-RRAAT8-052.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/TPT-RRTPLuke5-179.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/KDN-RRKDZLuke2-103.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/KDN-RRKDZLuke2-100.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/TPT-RRTPLuke5-189.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/TPT-RRTPLuke5-158.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/TPT-RRTPLuke5-043.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/AAN-RRAAT8-145.wav
#   inflating: /content/drive/MyDrive/CS72FinalProject/cim-wavs/wav/KDN-RRKDZLuke2-048.wav
# ...

# %%
# !nproc
# Out:
# 8

# %%
# !conda run -n aligner mfa validate --clean --single_speaker --num_jobs 8 /content/drive/MyDrive/CS72FinalProject/cim-corpus/wav /content/drive/MyDrive/CS72FinalProject/pronunciation_dictionary.txt
# Out:
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5,422/100  [ 0:02:43 < 0:00:00 , 250 it/s ]
#   93% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸    5,067/5,422  [ 0:00:01 < 0:00:01 , 3,895 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5,419/5,422  [ 0:00:26 < 0:00:01 , 317 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5,419/5,422  [ 0:00:03 < 0:00:01 , 1,680 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5,419/5,422  [ 0:00:01 < 0:00:01 , 5,023 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2,000/2,000  [ 0:00:01 < 0:00:00 , 1,916 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2,008/2,000  [ 0:00:02 < 0:00:00 , 818 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2,000/2,000  [ 0:00:09 < 0:00:00 , 221 it/s ]
#   87% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸       1,737/2,000  [ 0:00:01 < 0:00:01 , 1,343 it/s ]
# ...

# %%
# !conda run -n aligner mfa train --verbose --clean --use_mp --single_speaker --num_jobs 4 /content/drive/MyDrive/CS72FinalProject/test-align /content/drive/MyDrive/CS72FinalProject/pronunciation_dictionary.txt /content/drive/MyDrive/CS72FinalProject/new_acoustic_model.zip --output_directory /content/drive/MyDrive/CS72FinalProject/cim_corpus_aligned
# Out:
#    5% ━━╸                                                      5/100  [ 0:00:01 < -:--:-- , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:02 < 0:00:00 , 2 it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/5  [ 0:00:01 < 0:00:00 , ? it/s ]
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5  [ 0:00:01 < 0:00:00 , ? it/s ]
# ...
